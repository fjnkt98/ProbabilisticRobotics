# %%
import sys
sys.path.append("../scripts/")
from robot import *

# %%
import copy

world = World(40.0, 0.1)

initial_pose = np.array([0, 0, 0]).T
robots = []
r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))

for i in range(100):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
import pandas as pd
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots],
                    columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      3.922701  3.929028  3.930486  3.928474  3.918111  3.908569  3.857435
# theta  0.120620 -0.131178  0.059161  0.178190  0.141867 -0.335500  0.698051
#
#              7         8         9   ...        90        91        92  \
# r      3.920135  3.865153  3.926754  ...  3.921293  3.891991  3.930817
# theta -0.298965  0.509966  0.169273  ...  0.168885  0.355219  0.248455
#
#              93        94        95        96        97        98        99
# r      3.900388  3.911619  3.929492  3.919760  3.922092  3.924355  3.923853
# theta  0.340268  0.291212 -0.024656 -0.131849  0.025506 -0.242781  0.187457
#
# [2 rows x 100 columns]

# %%
print(poses["theta"].var())
print(poses["r"].mean())
math.sqrt(poses["theta"].var()/poses["r"].mean())
# Out:
# 0.05474725627443912
# 3.917281065301675
# 0.11821941685560451
