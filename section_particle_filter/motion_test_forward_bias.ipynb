# %%
import sys
sys.path.append("../scripts/")
from robot import *

# %%
world = World(40.0, 0.1)

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
import pandas as pd
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots],
                    columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      3.528861  4.174736  3.483888  3.271305  4.230286  3.897171  3.747622
# theta -0.614082 -0.147548 -0.266521  0.052994 -0.440156 -0.183443  0.306802
#
#              7         8         9   ...        90        91        92  \
# r      4.746949  4.445655  3.289189  ...  4.514443  3.483732  3.839923
# theta  0.071431 -0.053458 -0.021070  ...  0.140338  0.047039 -0.149591
#
#              93        94        95        96        97        98        99
# r      4.472708  3.632605  4.757059  4.406740  3.401960  4.202912  3.512526
# theta  0.042191 -0.000599 -0.046023 -0.220039  0.005556 -0.133498 -0.272189
#
# [2 rows x 100 columns]

# %%
print(poses["r"].var())
print(poses["r"].mean())
math.sqrt(poses["r"].var()/poses["r"].mean())
# Out:
# 0.1654487898286595
# 3.997034733172008
# 0.20345240891337646
